# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from segmentflow import segment, view
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
props_csv_path = Path(
    '../results/IP_01_he6-raw_segmentflow/IP_01_STLs/IP_01_properties.csv'
)
props_df = pd.read_csv(props_csv_path, index_col=0).sort_values('particleID')
props_df.head()
# Out:
#             meshed   n_voxels       centroid  min_slice  max_slice  min_row  \
# particleID
# 1             True  118568209  316, 319, 495          0       1010       12
# 6             True         47    322, 272, 3          2          6      270
# 9            False          1    327, 396, 3          3          4      396
# 10           False         15    338, 292, 4          3          6      291
# 13            True        128    354, 254, 4          2          7      250
#
#             max_row  min_col  max_col
# particleID
# 1               624        2      625
# 6               274      319      325
# 9               397      327      328
# 10              293      337      341
# 13              258      351      358

# %%
sieve_csv_path = Path('../data/F50-sieve.csv')
sieve_df = pd.read_csv(sieve_csv_path, index_col=0).sort_values('um')
sieve_df.head()
# Out:
#    usa     um  pct-retained
# 8  270   53.0           0.0
# 7  200   75.0           0.2
# 6  140  106.0           3.0
# 5  100  150.0          15.0
# 4   70  212.0          37.0

# %%
n_voxels = props_df['n_voxels'].to_numpy()
sieve_bins = sieve_df['um'].to_numpy()
ums_per_pixel = 8.434786
typical_pct_retained = sieve_df['pct-retained'].to_numpy()
fig, ax = view.size_distribution_spherical(
    n_voxels, sieve_bins, ums_per_pixel, typical_pct_retained)
ax.legend()
plt.show()
